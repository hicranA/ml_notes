# %% [markdown]
# # Machine Learning
# I like to teach myself. The way that I usually learn is by researching and explaining my myself what I have learned. So I decided to create these notebooks to keep track of my learning progress and reinforce my learning.<br>
# Sources:<br>
# "MACHINE LEARNING An Algorithmic Perspective Second Edition- Stephen Marsland (Module I)
#
# ## Module I - Intro

# %% [markdown]
# **Machine Learning Diagram**
# ![MachineLearning_diagram.jpg](attachment:MachineLearning_diagram.jpg)

# %% [markdown]
# ### <font color='Green'>Learning</font>
#
# When we think about machine learning we first need to think about
#  asking ourselves what is learning. The reason why is that we are attempting to copy our ability to learn so that machines can learn and do our boring and dirty work.  Here are the most important parts of learning;
# - remembering
# - adapting
# - generalising<br>
#
#
# #### <font color='Green'> - Machine Learning</font>
# I always forget definitions, and therefore instead of remembering the definition of machine learning  I want to remember why we need machine learning. We need machine learning because we want to solve some problems and by doing that we want them to learn remember and adapt and generalize.
# ##### <font color='Green'> * Supervised Learning</font>:
# Let's say I have multiple questions before I ask you questions I will give you example questions and answers. I want you to learn how to solve the problem based on example questions and anwers. After you complete your learning I will start asking you real questions and I want you to provide me the answers for them.
# ##### <font color='Green'> * Unsupervised learning </font>:
# In this case I will not give you answers but I will ask you questions and you will try to find patern from the data that I gave you and try to answer my questions based on your findings.
# ##### <font color='Green'> * Reinforcement learning </font>:
# Like the unsupervised learning I will not give you answers but I will let you know each time you answer wrong.
# ##### <font color='Green'> * Evolutionary learning </font>:
# In this case, we will look at the biological organisms to see how they adapt and learn. I did not heard much about evolutionary learning but I am excited to learn more about it.

# %% [markdown]
# ----------------
# #### <font color='Blue'> Important concepts to remember</font>
#
# Generalization: As we mentioned as humans we do generalization all the time. We do not always get steps by step instructions to do our daily tasks or our work. We train and after training, we are ready to use our training data to find answers to new problems.
#
# -----

# %% [markdown]
# #### <font color='Green'> - Supervised Learning</font>
# ##### <font color='Green'> # Regression </font>:
# In regression problem we need to provide some data points to our algroithm and our algroithm finds the a fit to our questions. I think most important thing in here to remember that our algorithm  uses generelazing.
# (further read: Regression Problems)
# ##### <font color='Green'> # Classification </font>:
# Sometimes we want to group things pr classify things based on input parameters. For example at work we want to identify which emails are spam and which emails are not.

# %% [markdown]
# ----------------
# #### <font color='Blue'> Note </font>
#
# I did not inculude a lot of details about regression and classification. Since I will write more details about these later.
#
# -----

# %% [markdown]
# #### <font color='Green'> - ML Process </font>
# ##### <font color='Green'> # Data Collection and Preparation: </font>
# When we have a new problem we might want to collect data or gather data. In this case, we need to think about what data might be relevant to us, how much data we need, what data format we need to choose, and so forth.
# ##### <font color='Green'> # Feature Selection: </font>
# When we have a new problem we might want to collect data or gather data. In this case, we need to think about what data might be relevant to us, how much data we need, what data format we need to choose, and so forth.
